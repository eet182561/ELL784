# %%
import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
from scipy.linalg import eigh
from sklearn.svm import SVC as svc
from matplotlib.colors import ListedColormap
from mlxtend.plotting import plot_decision_regions
data =Path('data')

# %%
sample_img = 'data/subject01.centerlight'

# %%
test = {}
train = {}
subject_data = {}
for file_name in data.glob('subject*'):
    subject_data[file_name.stem] = subject_data.get(file_name.stem,[]) + [file_name]
    
for key,value in subject_data.items():
    test[key] = value[-2:]
    train[key] = value[:-2]
    
h = 243
w = 320
img_size  = (h,w)
N = 3
small_img_size = (h//N,w//N)

# %%
def create_dataset(ids):
    '''
    Pass the subject ids as argument list.
    Default train test split is to chose 9 pictures for train and 2 pictures for test.
    Returns x_train,y_train,x_test,y_test
    '''
    x_train = [(cv2.resize(plt.imread(img),(w//N,h//N)).reshape(-1,1),id_) for id_ in ids for img in train[id_]]
    y_train = [id_ for id_ in ids for img in train[id_]]
    x_test =  [(cv2.resize(plt.imread(img),(w//N,h//N)).reshape(-1,1),id_) for id_ in ids for img in  test[id_]]
    y_test = [id_ for id_ in ids for img in test[id_]]

    x_train_array = np.empty((x_train[0][0].shape[0],len(x_train)))

    for i,(x,y) in enumerate(x_train):
        x_train_array[:,i]  = x.squeeze()


    x_test_array = np.empty((x_test[0][0].shape[0],len(x_test)))
    for i,(x,y) in enumerate(x_test):
        x_test_array[:,i]  = x.squeeze()
    
    return x_train_array, y_train,x_test_array,y_test

def ids_to_int(ids):
    return np.array([int(id_[-2:]) for id_ in ids])

# %%
ids = ['subject01','subject02']
x_train,y_train,x_test,y_test = create_dataset(ids)
mu = np.mean(x_train,axis=1,keepdims=True)
S_t = np.dot((x_train-mu),(x_train-mu).T)

e,v = eigh(S_t)
highest_e_args = np.argsort(-e)

e = e[highest_e_args]
v = v[highest_e_args]

print(f'highest eigen values are {e[:2]} and corresponding vectors {v[:2]}')
# Out:
# highest eigen values are [1.28096018e+08 6.72293494e+07] and corresponding vectors [[ 0.00125546  0.00775474  0.01922648 ... -0.00624446 -0.0026134
#   -0.01609784]
#  [ 0.04406256  0.04028376 -0.01631427 ... -0.00353872 -0.00097773
#   -0.01510011]]

# %%
def plot_figs(ncols,x,title):
    fig = plt.figure(figsize=(15,5))
    for i in range(x.shape[1]):
        ax = fig.add_subplot(len(ids),ncols,i+1)
        ax.imshow(x[:,i].reshape(small_img_size),cmap='gray')
        ax.axis('off')
    fig.suptitle(title)
    fig.show()

    
plot_figs(9,x_train,'Train Pics')
plot_figs(2,x_test,'Test Pics')
# Out:
# /tmp/ipykernel_84553/2689870061.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def transform_to_ND(v,components,X):
    W = v[:,components]
    return np.dot(W.T,X).T


x_train_pca_2d = transform_to_ND(v,[1,2],x_train)
x_test_pca_2d = transform_to_ND(v,[1,2],x_test)

# %%
import pandas as pd
import seaborn as sns
def create_df(x_train,y_train,name):
    df = pd.DataFrame()
    df['x'] = x_train[:,0]
    df['y'] = x_train[:,1]
    df['target'] = y_train
    df['name'] = name
    return df

# %%
df_pca_train = create_df(x_train_pca_2d,y_train,'train')
df_pca_test = create_df(x_test_pca_2d,y_test,'test')
df_pca = pd.concat([df_pca_train,df_pca_test])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_pca,x='x',y='y',hue='target',style='name')
plt.show()

# %% [markdown]
# # Fisher Faces

# %% [markdown]
# ## Between class and within class scatter matrix
#
# Here are the steps followed to calculate between class and within class scatter
# * Calculate the mean of each cluster (use information from the labels) $\mu_{i}$
# * Calculate the mean of whole dataset $\mu$
# * Calculate between class scatter $S_{B} = \sum\limits_{i=1}^{c}N_{i}(\mu_{i}-\mu)(\mu_{i}-\mu)^{T}$
# * Calculate within class scatter $S_{W} = \sum\limits_{i=1}^{c}\sum\limits_{x_{k} \in X_{i}}(x_{k}-\mu_{i})(x_{k}-\mu_{i})^{T}$

# %%
'''
class mean calculation
'''
data_x = {}
mean_x = {}

for x,subject in zip(x_train.T,y_train):
    data_x[subject] = data_x.get(subject,list())+[x]

for subject,data in data_x.items():
    mean_x[subject] = np.mean(np.array(data), axis=0)

dataset_mean = np.mean(x_train,axis=1)

S_B = np.zeros(((h//N)*(w//N),(h//N)*(w//N)))
for id in ids:
    N_i  = len(data_x[id])
    S_B += N_i*np.dot((mean_x[id] - dataset_mean),(mean_x[id] - dataset_mean).T)

S_W = np.zeros(((h//N)*(w//N),(h//N)*(w//N)))
for id in ids:
    for x_i in data_x[id]:
        S_W += np.dot((x_i - mean_x[id]),(x_i-mean_x[id]).T)

# %% [markdown]
# ## $S_{w}$ comes out to be singular
#
# The within class scatter comes out to be singular and hence non invertible. This happens because the training data is less than the features(number of pixels in each iamge) For this "Fisher Faces" trick is used, where the images are converted to lower dimension using PCA and then LDA is applied on the reduced dimensions.

# %%
principle_c = 5
c = v.shape[0] - principle_c

W_pca = v[:,:principle_c]

S_B_fld  = np.dot(np.dot(W_pca.T,S_B),W_pca)
S_W_fld  = np.dot(np.dot(W_pca.T,S_W),W_pca)
# Out:
# (5, 5) (5, 5)

# %%
e_fld,v_fld = eigh(np.linalg.inv(S_W_fld)*S_B_fld)
highest_e_args = np.argsort(-e_fld)
e_fld = e_fld[highest_e_args]
v_fld = v_fld[highest_e_args]

# %%
x_train_fld_2d = transform_to_ND(v_fld,[0,1],transform_to_ND(v,[0,1,2,3,4],x_train).T)
x_test_fld_2d = transform_to_ND(v_fld,[0,1],transform_to_ND(v,[0,1,2,3,4],x_test).T)

# %%
df_fld_train = create_df(x_train_fld_2d,y_train,'train')
df_fld_test = create_df(x_test_fld_2d,y_test,'test')
df_fld = pd.concat([df_fld_train,df_fld_test])

plt.figure(figsize=(8,8))
sns.scatterplot(data=df_fld,x='x',y='y',hue='target',style='name')
plt.show()

# %% [markdown]
# # Evaluating accuracy for 2 classes

# %% [markdown]
# ## PCA

# %%
from sklearn.neighbors import KNeighborsClassifier

reduced_dimensions = [0,1,2,3] #Remove the principle component to reduce the lighting effect
x_train_pca_reduced = transform_to_ND(v,reduced_dimensions,x_train)
x_test_pca_reduced = transform_to_ND(v,reduced_dimensions,x_test)

def evaluation(x_train,y_train,x_test,y_test):
    knn = KNeighborsClassifier(n_neighbors=3)
    knn.fit(x_train, y_train) 
    prediction = knn.predict(x_test)
    print(f'The test accuracy is {np.sum(y_test==prediction)/len(y_test)*100}')

print('For PCA: ')
evaluation(x_train_pca_reduced,y_train,x_test_pca_reduced,y_test)
# Out:
# For PCA:
# The test accuracy is 75.0

# %% [markdown]
# ## FLD

# %%
x_train_fld_reduced = transform_to_ND(v_fld,[0,1],transform_to_ND(v,[0,1,2,3,4],x_train).T)
x_test_fld_reduced = transform_to_ND(v_fld,[0,1],transform_to_ND(v,[0,1,2,3,4],x_test).T)

print('For FLD: ')
evaluation(x_train_fld_reduced,y_train,x_test_fld_reduced,y_test)
# Out:
# For FLD:
# The test accuracy is 100.0

# %% [markdown]
# Even with just two components FLD performs better than PCA for 2 class case.

# %% [markdown]
# # More than 2 classes
#
# From this section we incorporate all classes

# %%
ids = ['subject01','subject02','subject03','subject04','subject05','subject06',
      'subject07','subject08','subject09','subject10','subject11']
x_train,y_train,x_test,y_test = create_dataset(ids)
mu = np.mean(x_train,axis=1,keepdims=True)
S_t = np.dot((x_train-mu),(x_train-mu).T)

e,v = eigh(S_t)
highest_e_args = np.argsort(-e)

e = e[highest_e_args]
v = v[highest_e_args]

print(f'highest eigen values are {e[:2]} and corresponding vectors {v[:2]}')
# Out:
# highest eigen values are [1.18773380e+09 6.08852554e+08] and corresponding vectors [[-0.00920948  0.0037465   0.01877653 ... -0.00210449  0.01617371
#    0.00773956]
#  [ 0.02818268 -0.01589608  0.0144682  ... -0.00532338  0.01331498
#    0.00957667]]

# %%
plot_figs(9,x_train,'Train Pics')
plot_figs(2,x_test,'Test Pics')
# Out:
# /tmp/ipykernel_84553/2689870061.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
list(zip(x_train.T,y_train))
# Out:
# [(array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([255., 255., 255., ..., 180., 209., 207.]), 'subject01'),
#  (array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([255., 255., 255., ..., 252., 255., 253.]), 'subject01'),
#  (array([255., 255., 255., ..., 255., 255., 255.]), 'subject01'),
#  (array([237., 255., 255., ..., 185., 184., 173.]), 'subject02'),
#  (array([239., 255., 255., ..., 194., 191., 178.]), 'subject02'),
#  (array([237., 255., 255., ..., 185., 184., 173.]), 'subject02'),
#  (array([238., 255., 255., ..., 192., 190., 179.]), 'subject02'),
#  (array([238., 255., 255., ..., 185., 185., 174.]), 'subject02'),
# ...

# %%
'''
class mean calculation
'''
data_x = {}
mean_x = {}

for x,subject in zip(x_train.T,y_train):
    data_x[subject] = data_x.get(subject,list())+[x]
    
    
for subject,data in data_x.items():
    mean_x[subject] = np.mean(np.array(data), axis=0)

dataset_mean = np.mean(x_train,axis=1)


S_B = np.zeros(((h//N)*(w//N),(h//N)*(w//N)))
for id in ids:
    N_i  = len(data_x[id])
    S_B += N_i*np.dot((mean_x[id] - dataset_mean),(mean_x[id] - dataset_mean).T)

S_W = np.zeros(((h//N)*(w//N),(h//N)*(w//N)))
for id in ids:
    for x_i in data_x[id]:
        S_W += np.dot((x_i - mean_x[id]),(x_i-mean_x[id]).T)

# %%
e,v = eigh(np.linalg.inv(S_W)*S_B)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 e,v = eigh(np.linalg.inv(S_W)*S_B)
#
# File <__array_function__ internals>:200, in inv(*args, **kwargs)
#
# File ~/IITD/PhD/ELL784/fisher/Asg2/venv/lib/python3.8/site-packages/numpy/linalg/linalg.py:538, in inv(a)
#     536 signature = 'D->D' if isComplexType(t) else 'd->d'
#     537 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 538 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     539 return wrap(ainv.astype(result_t, copy=False))
#
# File ~/IITD/PhD/ELL784/fisher/Asg2/venv/lib/python3.8/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
class_means = {}

N_ = {}
data_x = {}
for subject,filepathlist in subject_data.items():
    sum_arr = np.zeros(((h//N)*(w//N),1))
    for filepath in filepathlist:
        data_x[subject] = data_x.get(subject,list())+[cv2.resize(plt.imread(filepath),(w//N,h//N)).reshape(-1,1)] 
        sum_arr += cv2.resize(plt.imread(filepath),(w//N,h//N)).reshape(-1,1)
    class_means[subject] = sum_arr/len(filepathlist)
    
    N_[subject] = len(filepathlist)

    
dataset_mean = np.zeros(((h//N)*(w//N),1))

total = 0
for subject,mean in class_means.items():
    dataset_mean += mean
    total += N_[subject]

dataset_mean = dataset_mean/total

S_B = np.zeros(((h//N)*(w//N),(h//N)*(w//N)))
for subject,mean in class_means.items():
    S_B += N_[subject]*np.dot((mean-dataset_mean),(mean-dataset_mean).T)
    

S_W = np.zeros(((h//N)*(w//N),(h//N)*(w//N)))
for subject,mean in class_means.items():
    for x in data_x[subject]:
        S_W += N_[subject]*np.dot((x-mean),(x-mean).T)

# %%
e,v = eigh(np.linalg.inv(S_W)*S_B)

# %%
highest_e_args = np.argsort(-e)

e = e[highest_e_args]
v = v[highest_e_args]

# %%
v
# Out:
# array([[-4.52930132e-05, -3.07571440e-06,  3.97627153e-04, ...,
#         -2.69082779e-04, -1.26693012e-04,  1.65628919e-04],
#        [ 2.76313875e-05, -1.16756626e-05, -3.86297024e-04, ...,
#          2.86510922e-04,  1.52616497e-04, -2.30115316e-04],
#        [ 2.30254450e-05, -1.73539174e-06, -2.92367207e-04, ...,
#          2.23448892e-04,  1.17938395e-04, -1.43288090e-04],
#        ...,
#        [ 1.24665888e-03,  2.21526470e-02, -3.49570492e-02, ...,
#         -1.71069721e-02, -3.03858375e-02, -1.81554174e-02],
#        [ 2.22717690e-03,  4.02690640e-04,  2.95473430e-03, ...,
#          4.29216173e-03,  9.40586728e-04, -2.84805191e-03],
#        [ 6.21472966e-03,  1.87826219e-02, -1.01796543e-02, ...,
#          6.75859460e-03, -1.60719039e-02, -1.45474937e-02]])

# %%
x = np.arange(-160,25,1)
y = []
for i,subject in enumerate(ids):
    y.append(-(svm.coef_[i][0]*x + svm.intercept_[i])/svm.coef_[i][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 4
#       2 y = []
#       3 for i,subject in enumerate(ids):
# ----> 4     y.append(-(svm.coef_[i][0]*x + svm.intercept_[i])/svm.coef_[i][1])
#
# File ~/IITD/PhD/ELL784/fisher/Asg2/venv/lib/python3.8/site-packages/sklearn/svm/_base.py:658, in BaseLibSVM.coef_(self)
#     651 """Weights assigned to the features when `kernel="linear"`.
#     652
#     653 Returns
#     654 -------
#     655 ndarray of shape (n_features, n_classes)
#     656 """
#     657 if self.kernel != "linear":
# --> 658     raise AttributeError("coef_ is only available when using a linear kernel")
#     660 coef = self._get_coef()
#     662 # coef_ being a read-only property, it's better to mark the value as
#     663 # immutable to avoid hiding potential bugs for the unsuspecting user.
#
# ...

# %%
svm.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': 10000000,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
plt.figure(figsize=(15,15))
colors = ListedColormap(["red","green","blue"])

le1 = []
#scatter = plt.scatter(x_pca_test.T[:,0],x_pca_test.T[:,1] ,cmap=colors,c= [0]*2 + [1]*2 +[2]*2,marker = 'x')
#le1 = scatter.legend_elements()[0]
scatter = plt.scatter(x_pca_train.T[:,0],x_pca_train.T[:,1] ,cmap = colors,c=[0]*9+[1]*9+[2]*9)
le2 = scatter.legend_elements()[0]
plt.legend(handles=le1+le2, labels=['test_subject_1','test_subject_2','train_subject_1','train_subject_2'])

# Plotting lines
for i,yy in enumerate(y):
    plt.plot(x,yy,label=f'decision_boundary_{i}')
plt.show()

# %%
img = plt.imread('data/subject01.centerlight',format='gif')
plt.imshow(img,cmap='gray')
